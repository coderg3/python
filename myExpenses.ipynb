# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df=pd.read_excel("C:\\Users\\DELL\\Desktop\\myExpenses.xlsx","Sheet1")

# %%
df
# Out:
#                MonthlyExpenses  Amount  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                         soap     100         NaN         NaN         NaN
# 1                    detergent     100         NaN         NaN         NaN
# 2                        brush      40         NaN         NaN         NaN
# 3                      shampoo      30         NaN         NaN         NaN
# 4                         pads     100         NaN         NaN         NaN
# 5   fair an lovely/bb/cc/cream     100         NaN         NaN         NaN
# 6                  moisturiser     100         NaN         NaN         NaN
# 7                        power      20         NaN         NaN         NaN
# 8                      colgate      50         NaN         NaN         NaN
# 9                         RENT    6000         NaN         NaN         NaN
# 10                   Traveling    2000         NaN         NaN         NaN
# ...

# %%
df=df.dropna(how ='all')
df=df.dropna(thresh=0)

# %%
df
# Out:
#                                     Monthly Expenses Amount
# Traveling 2000 NaN NaN NaN NaN NaN               NaN

# %%
df.info
# Out:
# <bound method DataFrame.info of                                     Monthly Expenses Amount
# Traveling 2000 NaN NaN NaN NaN NaN               NaN       >

# %%
df=df.drop(22)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 22
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df

# %%
df.describe()

# %%
df.shape

# %%
ndf=df.isnull().sum()

# %%
df

# %%
df["Monthly Expenses"].unique()
